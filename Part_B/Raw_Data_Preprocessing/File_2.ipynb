# %%
# !pip install pandas --quiet

# %%
import pandas as pd

# %%
web_dev_df=pd.read_csv("~\Desktop\RPOOPS\Mini Project\Part_B\Raw_Data_Generated\Raw_web_dev_data.csv")
web_dev_df
# Out:
#     Unnamed: 0                     Name of company Address of company
# 0            0                             LOANTAP          AHMEDABAD  \
# 1            1                             VISTEON               PUNE
# 2            2                      GODREJ & BOYCE            KOLKATA
# 3            3                            ARCESIUM            KOLKATA
# 4            4                          MASTERCARD        NAVI MUMBAI
# 5            5                 ROCKWELL AUTOMATION            KOLKATA
# 6            6                             TCS R&I            HARYANA
# 7            7                         V CONSTRUCT              LATUR
# 8            8                          DANA INDIA             MUMBAI
# 9            9                       ZS ASSOCIATES              NOIDA
# 10          10                            ATOMBERG          HYDERABAD
# 11          11                       ZS ASSOCIATES            KOLKATA
# ...

# %%
web_dev_df.columns
# Out:
# Index(['Unnamed: 0', 'Name of company', 'Address of company', 'Phone Number',
#        'Email Address', 'Previous Visited COEP', 'Work Mode', 'Min CGPA',
#        'Seats for Boys', 'Seats for Girls',
#        'Number of Dead Backlogs permitted',
#        'Number of Active Backlogs permitted',
#        'Preffered month of visiting campus', 'Domain to Hire',
#        'Frontent Languages', 'Frontend Frameworks', 'Backend Languages',
#        'Backend Frameworks', 'Databases for Websites', 'Website Servers',
#        'Website Deployment', 'Website Testing Tools'],
#       dtype='object')

# %%
modified_web_dev_df=web_dev_df.drop(['Unnamed: 0','Address of company', 'Phone Number',
       'Email Address', 'Previous Visited COEP'],axis=1)
modified_web_dev_df
# Out:
#                        Name of company         Work Mode  Min CGPA
# 0                              LOANTAP    Work from Home       7.3  \
# 1                              VISTEON  Work from office       9.5
# 2                       GODREJ & BOYCE  Work from office       6.3
# 3                             ARCESIUM  Work from office       9.0
# 4                           MASTERCARD    Work from Home       8.5
# 5                  ROCKWELL AUTOMATION  Work from office       8.9
# 6                              TCS R&I  Work from office       8.1
# 7                          V CONSTRUCT    Work from Home       6.3
# 8                           DANA INDIA    Work from Home       7.0
# 9                        ZS ASSOCIATES  Work from office       7.2
# 10                            ATOMBERG  Work from office       7.4
# 11                       ZS ASSOCIATES    Work from Home       9.2
# 12        AMURA MARKETING TECHNOLOGIES  Work from office       8.4
# ...

# %%
modified_web_dev_df.to_csv("~\Desktop\RPOOPS\Mini Project\Part_B\Final_Data\Final_web_dev_data.csv")

# %%
app_dev_df=pd.read_csv("~\Desktop\RPOOPS\Mini Project\Part_B\Raw_Data_Generated\Raw_app_dev_data.csv")
app_dev_df
# Out:
#     Unnamed: 0                            Name of company Address of company
# 0            0                                    PIRAMAL        NAVI MUMBAI  \
# 1            1                             UGAM SOLUTIONS              NOIDA
# 2            2                                    SOC GEN         AURANGABAD
# 3            3                       HINDUJA TECH LIMITED          AHMEDABAD
# 4            4                                    TAVISCA             JAIPUR
# 5            5                        WINJIT TECHNOLOGIES              LATUR
# 6            6                                    VISTEON            HARYANA
# 7            7                                  TCS NINJA             JAIPUR
# 8            8                              BAJAJ FINSERV             NASHIK
# 9            9                                     NUANCE            CHENNAI
# 10          10                               ADOR WELDING              LATUR
# ...

# %%
modified_app_dev_df=app_dev_df.drop(['Unnamed: 0','Address of company', 'Phone Number',
       'Email Address', 'Previous Visited COEP'],axis=1)
modified_app_dev_df
# Out:
#                               Name of company         Work Mode  Min CGPA
# 0                                     PIRAMAL  Work from office       7.8  \
# 1                              UGAM SOLUTIONS    Work from Home       6.6
# 2                                     SOC GEN    Work from Home       7.7
# 3                        HINDUJA TECH LIMITED    Work from Home       9.9
# 4                                     TAVISCA    Work from Home       9.2
# 5                         WINJIT TECHNOLOGIES  Work from office       7.2
# 6                                     VISTEON  Work from office       7.7
# 7                                   TCS NINJA  Work from office       8.8
# 8                               BAJAJ FINSERV    Work from Home       6.7
# 9                                      NUANCE  Work from office       8.3
# 10                               ADOR WELDING    Work from Home       6.3
# 11                                   EY INDIA  Work from office       6.0
# ...

# %%
modified_app_dev_df.to_csv("~\Desktop\RPOOPS\Mini Project\Part_B\Final_Data\Final_app_dev_data.csv")

# %%
data_sci_df=pd.read_csv("~\Desktop\RPOOPS\Mini Project\Part_B\Raw_Data_Generated\Raw_data_sci_data.csv")
data_sci_df
# Out:
#     Unnamed: 0                        Name of company Address of company
# 0            0                                TCS R&I               PUNE  \
# 1            1                              ION GROUP              JAPAN
# 2            2                                PIRAMAL              NOIDA
# 3            3  SKF ENGINEERING AND LUBRICATION INDIA         AURANGABAD
# 4            4                              DAR GROUP              NOIDA
# ..         ...                                    ...                ...
# 63          63                     HIGHWAY 9 NETWORKS            CHENNAI
# 64          64                                 ZENSAR             NASHIK
# 65          65                             DANA INDIA            CHENNAI
# 66          66                        SIEMENS LIMITED             JAIPUR
# 67          67                             TCS XPLORE            KOLKATA
#
#     Phone Number                                     Email Address
# ...

# %%
modified_data_sci_df=data_sci_df.drop(['Unnamed: 0','Address of company', 'Phone Number',
       'Email Address', 'Previous Visited COEP'],axis=1)
modified_data_sci_df
# Out:
#                           Name of company         Work Mode  Min CGPA
# 0                                 TCS R&I  Work from office       9.4  \
# 1                               ION GROUP  Work from office       7.0
# 2                                 PIRAMAL  Work from office       8.3
# 3   SKF ENGINEERING AND LUBRICATION INDIA  Work from office       9.0
# 4                               DAR GROUP  Work from office       8.1
# ..                                    ...               ...       ...
# 63                     HIGHWAY 9 NETWORKS    Work from Home       9.2
# 64                                 ZENSAR    Work from Home       7.5
# 65                             DANA INDIA  Work from office       8.2
# 66                        SIEMENS LIMITED  Work from office       9.9
# 67                             TCS XPLORE  Work from office       8.1
#
#     Seats for Boys  Seats for Girls  Number of Dead Backlogs permitted
# ...

# %%
modified_data_sci_df.to_csv("~\Desktop\RPOOPS\Mini Project\Part_B\Final_Data\Final_data_sci_data.csv")

# %%
aiml_df=pd.read_csv("~\Desktop\RPOOPS\Mini Project\Part_B\Raw_Data_Generated\Raw_aiml_data.csv")
aiml_df
# Out:
#     Unnamed: 0                     Name of company Address of company
# 0            0  TATA STEEL DOWNSTREAM PRODUCTS LTD            HARYANA  \
# 1            1                       HERO MOTOCORP            GURGAON
# 2            2                         V CONSTRUCT            KOLKATA
# 3            3                     WHIRLPOOL INDIA            GURGAON
# 4            4                              GOOGLE             NASHIK
# ..         ...                                 ...                ...
# 68          68                       CREDIT SUISSE             NASHIK
# 69          69                        INFOGEN LABS            GUJARAT
# 70          70                     SIEMENS LIMITED          HYDERABAD
# 71          71                           AKZONOBEL          AHMEDABAD
# 72          72                              BETSOL            CHENNAI
#
#     Phone Number                                  Email Address
# ...

# %%
modified_aiml_df=aiml_df.drop(['Unnamed: 0','Address of company', 'Phone Number',
       'Email Address', 'Previous Visited COEP'],axis=1)
modified_aiml_df
# Out:
#                        Name of company         Work Mode  Min CGPA
# 0   TATA STEEL DOWNSTREAM PRODUCTS LTD  Work from office       9.9  \
# 1                        HERO MOTOCORP  Work from office       8.0
# 2                          V CONSTRUCT  Work from office       9.4
# 3                      WHIRLPOOL INDIA  Work from office       8.7
# 4                               GOOGLE    Work from Home       6.4
# ..                                 ...               ...       ...
# 68                       CREDIT SUISSE  Work from office       6.5
# 69                        INFOGEN LABS    Work from Home       9.6
# 70                     SIEMENS LIMITED  Work from office       7.5
# 71                           AKZONOBEL    Work from Home       9.0
# 72                              BETSOL  Work from office       9.7
#
#     Seats for Boys  Seats for Girls  Number of Dead Backlogs permitted
# 0                2                5                                  1  \
# ...

# %%
modified_aiml_df.to_csv("~\Desktop\RPOOPS\Mini Project\Part_B\Final_Data\Final_aiml_data.csv")

# %%
cloud_df=pd.read_csv("~\Desktop\RPOOPS\Mini Project\Part_B\Raw_Data_Generated\Raw_cloud_data.csv")
cloud_df
# Out:
#     Unnamed: 0                            Name of company Address of company
# 0            0                            SIEMENS LIMITED          HYDERABAD  \
# 1            1                                   SYNOPSYS          AHMEDABAD
# 2            2                                NBC BEARING        NAVI MUMBAI
# 3            3                                      IDEAS            KOLKATA
# 4            4                              ZS ASSOCIATES          HYDERABAD
# 5            5                                    LOANTAP              JAPAN
# 6            6                 SAARLOHA ADVANCE MATERIALS            CHENNAI
# 7            7                          FOURFRONT PVT.LTD             MUMBAI
# 8            8       HIRSCHVOGEL COMPONENTS INDIA PVT.LTD             NASHIK
# 9            9                                        ADM            HARYANA
# 10          10                          FOURFRONT PVT.LTD             MUMBAI
# ...

# %%
modified_cloud_df=cloud_df.drop(['Unnamed: 0','Address of company', 'Phone Number',
       'Email Address', 'Previous Visited COEP'],axis=1)
modified_cloud_df
# Out:
#                               Name of company         Work Mode  Min CGPA
# 0                             SIEMENS LIMITED    Work from Home       6.2  \
# 1                                    SYNOPSYS  Work from office       6.7
# 2                                 NBC BEARING  Work from office       6.3
# 3                                       IDEAS  Work from office       6.5
# 4                               ZS ASSOCIATES  Work from office       8.3
# 5                                     LOANTAP    Work from Home       7.1
# 6                  SAARLOHA ADVANCE MATERIALS    Work from Home       8.4
# 7                           FOURFRONT PVT.LTD    Work from Home       9.0
# 8        HIRSCHVOGEL COMPONENTS INDIA PVT.LTD    Work from Home      10.0
# 9                                         ADM  Work from office       8.6
# 10                          FOURFRONT PVT.LTD    Work from Home       8.6
# 11                                HOLTECCASIA    Work from Home       6.7
# ...

# %%
modified_cloud_df.to_csv("~\Desktop\RPOOPS\Mini Project\Part_B\Final_Data\Final_cloud_data.csv")

# %%
dbms_df=pd.read_csv("~\Desktop\RPOOPS\Mini Project\Part_B\Raw_Data_Generated\Raw_dbms_data.csv")
dbms_df
# Out:
#     Unnamed: 0                      Name of company Address of company
# 0            0                         CION DIGITAL           WALCHAND  \
# 1            1                              CENTRIO            KOLKATA
# 2            2                               ZENSAR        NAVI MUMBAI
# 3            3                              DEMATIC            CHENNAI
# 4            4  RENATA PRECISION COMPONENTS PVT.LTD              LATUR
# 5            5                   SHAPOORJI PALLONJI            HARYANA
# 6            6                           ICICI BANK             JAIPUR
# 7            7                            DAR GROUP            CHENNAI
# 8            8                      TALLY SOLUTIONS               PUNE
# 9            9              ENERGY MACHINES PVT.LTD        NAVI MUMBAI
# 10          10                             EY INDIA              NOIDA
# 11          11              ENERGY MACHINES PVT.LTD               PUNE
# ...

# %%
modified_dbms_df=dbms_df.drop(['Unnamed: 0','Address of company', 'Phone Number',
       'Email Address', 'Previous Visited COEP'],axis=1)
modified_dbms_df
# Out:
#                         Name of company         Work Mode  Min CGPA
# 0                          CION DIGITAL  Work from office       9.1  \
# 1                               CENTRIO    Work from Home       7.6
# 2                                ZENSAR    Work from Home       9.4
# 3                               DEMATIC  Work from office       8.7
# 4   RENATA PRECISION COMPONENTS PVT.LTD    Work from Home       6.8
# 5                    SHAPOORJI PALLONJI  Work from office       6.9
# 6                            ICICI BANK  Work from office       8.1
# 7                             DAR GROUP    Work from Home       9.0
# 8                       TALLY SOLUTIONS    Work from Home       9.9
# 9               ENERGY MACHINES PVT.LTD  Work from office       8.6
# 10                             EY INDIA  Work from office       9.0
# 11              ENERGY MACHINES PVT.LTD    Work from Home       8.0
# 12                                FINIQ    Work from Home       8.3
# ...

# %%
modified_dbms_df.to_csv("~\Desktop\RPOOPS\Mini Project\Part_B\Final_Data\Final_dbms_data.csv")

# %%
devops_df=pd.read_csv("~\Desktop\RPOOPS\Mini Project\Part_B\Raw_Data_Generated\Raw_devops_data.csv")
devops_df
# Out:
#     Unnamed: 0                     Name of company Address of company
# 0            0  SHAH TECHNICAL CONSULTANTS PVT.LTD             NASHIK  \
# 1            1                  SHAPOORJI PALLONJI            GUJARAT
# 2            2                    ICICI SECURITIES           WALCHAND
# 3            3                   TATA TECHNOLOGIES            GUJARAT
# 4            4                      TEJAS NETWORKS             MUMBAI
# ..         ...                                 ...                ...
# 66          66                ARMSTRONG AUTOMATION            HARYANA
# 67          67                             SOC GEN               PUNE
# 68          68                    CITI CORPORATION          BANGALORE
# 69          69                             SOC GEN             JAIPUR
# 70          70                  SHAPOORJI PALLONJI              JAPAN
#
#     Phone Number                                   Email Address
# ...

# %%
modified_devops_df=devops_df.drop(['Unnamed: 0','Address of company', 'Phone Number',
       'Email Address', 'Previous Visited COEP'],axis=1)
modified_devops_df
# Out:
#                        Name of company         Work Mode  Min CGPA
# 0   SHAH TECHNICAL CONSULTANTS PVT.LTD  Work from office       9.9  \
# 1                   SHAPOORJI PALLONJI    Work from Home       8.5
# 2                     ICICI SECURITIES  Work from office       8.5
# 3                    TATA TECHNOLOGIES  Work from office       7.1
# 4                       TEJAS NETWORKS    Work from Home       7.9
# ..                                 ...               ...       ...
# 66                ARMSTRONG AUTOMATION    Work from Home       6.1
# 67                             SOC GEN  Work from office       9.2
# 68                    CITI CORPORATION    Work from Home       7.4
# 69                             SOC GEN  Work from office       7.6
# 70                  SHAPOORJI PALLONJI  Work from office       9.5
#
#     Seats for Boys  Seats for Girls  Number of Dead Backlogs permitted
# 0               10                0                                  1  \
# ...

# %%
modified_devops_df.to_csv("~\Desktop\RPOOPS\Mini Project\Part_B\Final_Data\Final_devops_data.csv")

# %%
cs_df=pd.read_csv("~\Desktop\RPOOPS\Mini Project\Part_B\Raw_Data_Generated\Raw_cs_data.csv")
cs_df
# Out:
#     Unnamed: 0                        Name of company Address of company
# 0            0                               MICHELIN          HYDERABAD  \
# 1            1                                TAVISCA            CHENNAI
# 2            2                          CREDIT SUISSE              JAPAN
# 3            3                      REIANCE JIO MEDIA          BANGALORE
# 4            4                                 DESHAW            CHENNAI
# 5            5                          MERCEDES BENZ          BANGALORE
# 6            6                               FAURECIA             MUMBAI
# 7            7                                  HELLA            GUJARAT
# 8            8                               VODAFONE          HYDERABAD
# 9            9                                 GOOGLE             MUMBAI
# 10          10                      TEXAS INSTRUMENTS         AURANGABAD
# 11          11                          MICROLAND LTD             JAIPUR
# ...

# %%
modified_cs_df=cs_df.drop(['Unnamed: 0','Address of company', 'Phone Number',
       'Email Address', 'Previous Visited COEP'],axis=1)
modified_cs_df
# Out:
#                           Name of company         Work Mode  Min CGPA
# 0                                MICHELIN  Work from office       9.9  \
# 1                                 TAVISCA  Work from office       9.3
# 2                           CREDIT SUISSE  Work from office       6.4
# 3                       REIANCE JIO MEDIA  Work from office       8.4
# 4                                  DESHAW  Work from office       6.7
# 5                           MERCEDES BENZ  Work from office       9.2
# 6                                FAURECIA    Work from Home       8.9
# 7                                   HELLA  Work from office       6.0
# 8                                VODAFONE    Work from Home       7.4
# 9                                  GOOGLE    Work from Home       6.3
# 10                      TEXAS INSTRUMENTS    Work from Home       8.7
# 11                          MICROLAND LTD  Work from office       6.3
# ...

# %%
modified_cs_df.to_csv("~\Desktop\RPOOPS\Mini Project\Part_B\Final_Data\Final_cs_data.csv")
